# %% [markdown]
# # 네이버 티비 : 영상 제목, 채널, 조회수, 좋아요 수

# %% [markdown]
# ## 컨테이너 수집

# %%
import requests
from bs4 import BeautifulSoup as bs
#from urllib.request import urlopen

# 소스코드 가져오기

# raw
raw = requests.get("https://tv.naver.com/r")
print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
print(raw.elapsed)
#print(raw.text) # 그저 txt

# 파싱하기
html = bs(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 컨테이너
clips = html.select("div.inner")
print(clips[0])
# Out:
# <Response [200]>
# 0:00:00.117133
# <div class="inner">
# <a class="box" data-anisrc="https://phinf.pstatic.net/tvcast/20210903_268/53Xmv_1630596161544NyncJ_GIF/99b77075-0bfd-11ec-aee3-a0369ff9072c.gif?type=mfullfill_406_228_ani_limit15" href="https://tv.naver.com/v/22226512/list/67096" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="임영웅X설운도 ‘별빛 같은 나의 사랑아’♬ 이 조합 영원하길..❤ TV CHOSUN 210902 방송" data-src="https://phinf.pstatic.net/tvcast/20210902_225/PzPdN_1630594596481xIiLe_JPEG/C202000040_3_202109021117398001.jpg?type=f406_228_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"' src="https://phinf.pstatic.net/tvcast/20210902_225/PzPdN_1630594596481xIiLe_JPEG/C202000040_3_202109021117398001.jpg?type=f406_228_blend"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0"/>
# <em class="time"><span class="blind">재생시간</span>3:47</em>
# <span class="btn_my _click" data-clipno="22226512" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.3add', '', '1', '');">담기</span>
# </a>
# <div class="info">
# <span class="num num1">1</span>
# <span class="rank up"><span class="blind">상승</span><em>1</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/22226512" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# <strong class="tit"><span>임영웅X설운도 ‘별빛 같은 나의 사랑아’♬ 이 조합 영원하길..❤ TV CHOSUN 210902 방송</span></strong>
# </a>
# </dt>
# <dd class="chn">
# <a class="ch" href="https://tv.naver.com/tvchosun.lovecall" onclick="clickcr(this, 'top.3chtitle', '', '1', event)">사랑의 콜센타</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>112,305</span>
# <span class="like"><span class="blind">좋아요 수</span>18,187</span>
# </dd>
# </dl>
# </div>
# </div>

# %% [markdown]
# ## 컨테이너 별 데이터 수집

# %%
import requests
from bs4 import BeautifulSoup

# 소스코드 가져오기
raw = requests.get("https://tv.naver.com/r")
print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
print(raw.elapsed)
#print(raw.text) # 그저 txt

#파싱하기
html = bs(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

#컨테이너
clips = html.select("div.inner") # select 함수는 BS4안에 포함된 함수, html로 파싱한 코드가 있는 변수에 사용
#print(clips[0])

# 데이터 찾기
title = clips[0].select_one("dt.title") 
chn = clips[0].select_one("dd.chn")
hit = clips[0].select_one("span.hit")
like = clips[0].select_one("span.like")

print(title)
print(title.text) # 텍스트만 출력
print(chn)
print(chn.text)
print(hit)
print(hit.text)
print(like.text)
# Out:
# <Response [200]>
# 0:00:00.072974
# <dt class="title">
# <a href="https://tv.naver.com/v/22226512" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# <strong class="tit"><span>임영웅X설운도 ‘별빛 같은 나의 사랑아’♬ 이 조합 영원하길..❤ TV CHOSUN 210902 방송</span></strong>
# </a>
# </dt>
#
#
# 임영웅X설운도 ‘별빛 같은 나의 사랑아’♬ 이 조합 영원하길..❤ TV CHOSUN 210902 방송
#
#
# <dd class="chn">
# <a class="ch" href="https://tv.naver.com/tvchosun.lovecall" onclick="clickcr(this, 'top.3chtitle', '', '1', event)">사랑의 콜센타</a>
# </dd>
#
# 사랑의 콜센타
#
# <span class="hit"><span class="blind">재생 수</span>112,298</span>
# 재생 수112,298
# 좋아요 수18,187

# %% [markdown]
# ## 수집반복

# %%
import requests
from bs4 import BeautifulSoup

# 소스코드 가져오기
raw = requests.get("https://tv.naver.com/r")
print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
print(raw.elapsed)
#print(raw.text) # 그저 txt

#파싱하기
html = bs(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 반복 수집


## 1~3위
n = 1

### 컨테이너
clips = html.select("div.inner") # select 함수는 BS4안에 포함된 함수, html로 파싱한 코드가 있는 변수에 사용, 1~3위
#print(clips[0])

for i in range(len(clips)) : # range() 활용
    print("=== [[", n, "위 ]]","="*35)
    title = clips[i].select_one("dt.title") # select 함수는 BS4안에 포함된 함수, html로 파싱한 코드가 있는 변수에 사용
    chn = clips[i].select_one("dd.chn")
    hit = clips[i].select_one("span.hit")
    like = clips[i].select_one("span.like")

    #print(title)
    print(title.text) # 텍스트만 출력
    #print(chn)
    print(chn.text.strip())
    #print(hit)
    print(hit.text.strip())
    print(like.text.strip())
    print("="*50)
    n = n + 1


## 4~100위

### 컨테이너
clips = html.select("div.cds") # 4~100위

for cl in clips: # 리스트 >> clips = [...]
    print("=== [[", n, "위 ]]","="*35)
    
    title = cl.select_one("dt.title")
    chn = cl.select_one("dd.chn")
    hit = cl.select_one("span.hit")
    like = cl.select_one("span.like")

    print("제목", title.text.strip())
    print("채널명", chn.text.strip())
    print(hit.text.strip())
    print(like.text.strip())
    print("="*50)
    n = n + 1
# Out:
# <Response [200]>
# 0:00:00.081290
# === [[ 1 위 ]] ===================================
#
#
# [월드컵 유럽 예선] 노르웨이 vs 지브롤터 골모음
#
#
# SPOTV
# 재생 수58,448
# 좋아요 수106
# ==================================================
# === [[ 2 위 ]] ===================================
#
#
# [월드컵 유럽 예선] 네덜란드 vs 터키 골모음
#
#
# SPOTV
# 재생 수41,995
# 좋아요 수83
# ==================================================
# === [[ 3 위 ]] ===================================
#
#
# 임영웅X설운도 ‘별빛 같은 나의 사랑아’♬ 이 조합 영원하길..❤ TV CHOSUN 210902 방송
#
#
# 사랑의 콜센타
# 재생 수119,673
# 좋아요 수18,470
# ==================================================
# === [[ 4 위 ]] ===================================
# 제목 남자 특집에 딱!이야 ‘My Way’♪ 브라보 김호중👏
# 채널명 사랑의 콜센타
# 재생 수565,413
# 좋아요 수27,124
# ==================================================
# === [[ 5 위 ]] ===================================
# 제목 [흑기사 엔딩] 안효섭, 위험 처한 김유정 지키기 위해 등장!
# 채널명 홍천기
# 재생 수84,350
# 좋아요 수803
# ==================================================
# === [[ 6 위 ]] ===================================
# 제목 레바논전 진땀승, 벤투 감독 "달라져야 하는 점 모르겠다" (월드컵 최종예선)
# 채널명 한준TV
# 재생 수63,655
# 좋아요 수96
# ==================================================
# === [[ 7 위 ]] ===================================
# 제목 경찰, '가세연' 운영진 강용석·김세의·김용호 체포
# 채널명 뉴스는 YTN
# 재생 수67,803
# 좋아요 수81
# ==================================================
# === [[ 8 위 ]] ===================================
# 제목 [월드컵 유럽 예선] 프랑스 vs 핀란드 골모음
# 채널명 SPOTV
# 재생 수39,059
# 좋아요 수68
# ==================================================
# === [[ 9 위 ]] ===================================
# 제목 생방송 하며 버틴 '가세연'…문 부수고 체포
# 채널명 SBS뉴스
# 재생 수33,538
# 좋아요 수42
# ==================================================
# === [[ 10 위 ]] ===================================
# 제목 [3회] 서브 계급 댄스 비디오 (Choreo by 원트 모아나&엠마) @계급 미션 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수92,652
# 좋아요 수450
# ==================================================
# === [[ 11 위 ]] ===================================
# 제목 [PL] '케없손왕!' 맨시티 킬러 손흥민의 리그 1호골!
# 채널명 SPOTV_PL
# 재생 수2,263,482
# 좋아요 수34,838
# ==================================================
# === [[ 12 위 ]] ===================================
# 제목 이번 커버도 찢었다..✨ 바닷바람 곁들인 이수현의 〈Butter〉♬ | JTBC 210907 방송
# 채널명 바라던 바다
# 재생 수51,306
# 좋아요 수715
# ==================================================
# === [[ 13 위 ]] ===================================
# 제목 안녕하세요 오늘은 록커 웅이에요😎 ‘비망록’♪ TV CHOSUN 210902 방송
# 채널명 사랑의 콜센타
# 재생 수130,100
# 좋아요 수21,735
# ==================================================
# === [[ 14 위 ]] ===================================
# 제목 [발견엔딩] 조여정, 사고 현장에서 발견한 머리핀의 주인 찾았다! | tvN 210907 방송
# 채널명 하이클래스
# 재생 수38,112
# 좋아요 수69
# ==================================================
# === [[ 15 위 ]] ===================================
# 제목 [3회] 언니들 싸움이란 이런 것(?) 프라우드먼 모니카 vs 홀리뱅 허니제이 @리더 계급 워스트 지목 배틀 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수77,699
# 좋아요 수735
# ==================================================
# === [[ 16 위 ]] ===================================
# 제목 [검거 엔딩] ‘잡았다 요놈!’ 돌발 상황에도 완벽한 파트너십으로 고교수 검거 성공♨ | KBS 210907 방송
# 채널명 경찰수업
# 재생 수37,582
# 좋아요 수262
# ==================================================
# === [[ 17 위 ]] ===================================
# 제목 ‘365일’♬ 전설의 노래로 승부하는 영탁★ TV CHOSUN 210902 방송
# 채널명 사랑의 콜센타
# 재생 수44,625
# 좋아요 수7,739
# ==================================================
# === [[ 18 위 ]] ===================================
# 제목 1600여 년 전 신라 여성 유골 발견…"인신공양 흔적"
# 채널명 JTBC뉴스
# 재생 수11,851
# 좋아요 수6
# ==================================================
# === [[ 19 위 ]] ===================================
# 제목 [월드컵 유럽 예선] '노리고 찼다!' 묘기에 가까운 B.실바의 원더골
# 채널명 SPOTV
# 재생 수37,209
# 좋아요 수89
# ==================================================
# === [[ 20 위 ]] ===================================
# 제목 안효섭, 김유정 두고 공명과 미묘한 기싸움
# 채널명 홍천기
# 재생 수32,577
# 좋아요 수451
# ==================================================
# === [[ 21 위 ]] ===================================
# 제목 김호중 ‘무정부르스’♩ 상한 성대도 뚫는⇴ 천상의 목소리
# 채널명 미스터트롯
# 재생 수801,020
# 좋아요 수13,556
# ==================================================
# === [[ 22 위 ]] ===================================
# 제목 [3회] 보아의 마음을 훔친 립제이의 포인트 안무! @ 메인 댄서 선발전(세컨드 계급) | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수57,912
# 좋아요 수213
# ==================================================
# === [[ 23 위 ]] ===================================
# 제목 [3회] 물러설 수 없는 승부! 훅 선윤경 vs 원트 이채연 @어시스트 계급 워스트 지목 배틀 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수62,038
# 좋아요 수413
# ==================================================
# === [[ 24 위 ]] ===================================
# 제목 [5회 예고] 안효섭, 그림 경연 대회 나가는 김유정에 전하는 응원★
# 채널명 홍천기
# 재생 수52,870
# 좋아요 수451
# ==================================================
# === [[ 25 위 ]] ===================================
# 제목 [3회] (줘도 못 받아먹네?) 노제의 안무 디렉팅이 답답한 리더 계급 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수57,764
# 좋아요 수260
# ==================================================
# === [[ 26 위 ]] ===================================
# 제목 이찬원 - 편의점 (Lee Chan Won - Convenience store), MBC 210904 방송
# 채널명 쇼! 음악중심
# 재생 수45,196
# 좋아요 수10,497
# ==================================================
# === [[ 27 위 ]] ===================================
# 제목 [3회] '죄송한데요 저희 윤경이..' 워스트로 뽑힌 훅 선윤경, 리더 아이키의 반론은! | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수62,477
# 좋아요 수879
# ==================================================
# === [[ 28 위 ]] ===================================
# 제목 빚투족 막으려 무주택자 '전세대출 규제'?…세입자 우려
# 채널명 JTBC뉴스
# 재생 수13,664
# 좋아요 수3
# ==================================================
# === [[ 29 위 ]] ===================================
# 제목 '호타준족의 탄생!' 손성빈, 데뷔 첫 선발 경기 맹활약 [7AM]
# 채널명 크보연구소_네이버스포츠
# 재생 수18,428
# 좋아요 수304
# ==================================================
# === [[ 30 위 ]] ===================================
# 제목 안효섭×공명, 안절부절 사과하는 귀여운 김유정 모습에 미소♡
# 채널명 홍천기
# 재생 수29,747
# 좋아요 수384
# ==================================================
# === [[ 31 위 ]] ===================================
# 제목 안효섭, 김유정이 한 실수 듣고 빵 터진 웃음★
# 채널명 홍천기
# 재생 수30,178
# 좋아요 수364
# ==================================================
# === [[ 32 위 ]] ===================================
# 제목 [3회] '난 절대 지지 않아!' 워스트 댄서가 된 모니카의 모두를 놀라게 한 선전 포고 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수56,835
# 좋아요 수249
# ==================================================
# === [[ 33 위 ]] ===================================
# 제목 [3회] 피 터지는 신경전 속 메댄이 될 주인공은? @ 메인 댄서 선발전(서브 계급) 1차 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수45,779
# 좋아요 수310
# ==================================================
# === [[ 34 위 ]] ===================================
# 제목 [3회] '무대를 찢어버리자↗' YGX 여진&지효 vs 훅 예본&효우 @서브 계급 워스트 지목 배틀 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수53,502
# 좋아요 수300
# ==================================================
# === [[ 35 위 ]] ===================================
# 제목 [3회/풀캠] 리더 계급 댄스 비디오 @계급 미션 Full Cam
# 채널명 스트릿 우먼 파이터
# 재생 수17,102
# 좋아요 수118
# ==================================================
# === [[ 36 위 ]] ===================================
# 제목 [3회] 첫 탈락이 걸린 중요한 미션! 프라우드먼이 결정한 K-POP 4대 천왕 미션의 대진은? | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수43,318
# 좋아요 수153
# ==================================================
# === [[ 37 위 ]] ===================================
# 제목 "아흔 번째 생일 하루 앞두고"…음주차량에 치여 사망
# 채널명 MBC뉴스
# 재생 수11,106
# 좋아요 수2
# ==================================================
# === [[ 38 위 ]] ===================================
# 제목 [NEXT WEEK] (눈물의 연속) 스트릿 파이트 클럽을 떠나게 될 최초의 탈락 크루는?
# 채널명 스트릿 우먼 파이터
# 재생 수58,740
# 좋아요 수212
# ==================================================
# === [[ 39 위 ]] ===================================
# 제목 [3회] ♨지키느냐 뺏느냐♨ 최종 후보들의 치열한 각축전! @ 메인 댄서 선발전(서브 계급) 2차 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수50,744
# 좋아요 수290
# ==================================================
# === [[ 40 위 ]] ===================================
# 제목 [3회] '감정 싸움이 아니라..' 원트가 YGX를 무조건 워스트 댄서로 뽑으려는 이유는? | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수49,888
# 좋아요 수174
# ==================================================
# === [[ 41 위 ]] ===================================
# 제목 선제골에 무너진 '추풍낙엽' 침대 축구
# 채널명 GOAL TV
# 재생 수54,853
# 좋아요 수106
# ==================================================
# === [[ 42 위 ]] ===================================
# 제목 [3회] 주객전도, 시미즈없이는 진행이 안된다?! 위기의 어시스트 계급! | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수45,532
# 좋아요 수128
# ==================================================
# === [[ 43 위 ]] ===================================
# 제목 한정판에 명품에 없는 게 없었다…교묘해진 '짝퉁 시장'
# 채널명 JTBC뉴스
# 재생 수29,388
# 좋아요 수38
# ==================================================
# === [[ 44 위 ]] ===================================
# 제목 김웅 "통합당 선대위에 고발장 등 줬다"…당사자 반박
# 채널명 JTBC뉴스
# 재생 수11,193
# 좋아요 수1
# ==================================================
# === [[ 45 위 ]] ===================================
# 제목 안효섭, 가족을 잃게 한 왕실에 시작되는 복수!
# 채널명 홍천기
# 재생 수22,954
# 좋아요 수180
# ==================================================
# === [[ 46 위 ]] ===================================
# 제목 공명, 당돌한 무엄함 보이는 김유정에 흠칫!
# 채널명 홍천기
# 재생 수20,592
# 좋아요 수235
# ==================================================
# === [[ 47 위 ]] ===================================
# 제목 [3회] '너무 흥분한 나머지..?!' 홀리뱅 제인 vs 웨이비 리수 @세컨드 계급 워스트 지목 배틀 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수40,831
# 좋아요 수128
# ==================================================
# === [[ 48 위 ]] ===================================
# 제목 1년 3개월 지나서야 '텔레그램 대화방' 캡처…누가? 왜?
# 채널명 JTBC뉴스
# 재생 수19,067
# 좋아요 수30
# ==================================================
# === [[ 49 위 ]] ===================================
# 제목 채국희, 안효섭 몸 안에 마왕이 있음을 확신!
# 채널명 홍천기
# 재생 수20,451
# 좋아요 수135
# ==================================================
# === [[ 50 위 ]] ===================================
# 제목 [굿모닝] 정은경 "위드 코로나, 10월 말...마스크는 써야"
# 채널명 뉴스는 YTN
# 재생 수22,639
# 좋아요 수12
# ==================================================
# === [[ 51 위 ]] ===================================
# 제목 80대 운전 승용차, 중앙분리대 넘어 마을버스 등 충돌
# 채널명 연합뉴스TV
# 재생 수9,410
# 좋아요 수7
# ==================================================
# === [[ 52 위 ]] ===================================
# 제목 [3회] '길가의 나무 정도 존재감?' 홀리뱅 제인을 워스트 댄서로 지목한 라치카의 연이은 혹평 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수34,379
# 좋아요 수146
# ==================================================
# === [[ 53 위 ]] ===================================
# 제목 '수베로 vs 루친스키?!' 불문율과 수베로 그리고 루친스키 [7AM]
# 채널명 크보연구소_네이버스포츠
# 재생 수10,468
# 좋아요 수66
# ==================================================
# === [[ 54 위 ]] ===================================
# 제목 [월드컵 유럽 예선] '기선제압까지 54초' 데파이-클라선의 합작골!
# 채널명 SPOTV
# 재생 수16,280
# 좋아요 수38
# ==================================================
# === [[ 55 위 ]] ===================================
# 제목 [제보는Y] 농민 통행로 가로막은 철문..."철거 명령도 무시"
# 채널명 뉴스는 YTN
# 재생 수17,105
# 좋아요 수18
# ==================================================
# === [[ 56 위 ]] ===================================
# 제목 [3회] 어시스트 계급 댄스 비디오 (Choreo by 프라우드먼 헤일리) @계급 미션 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수45,459
# 좋아요 수154
# ==================================================
# === [[ 57 위 ]] ===================================
# 제목 탄도미사일 잠수함 발사 성공…"세계 8번째 SLBM 보유국"
# 채널명 MBC뉴스
# 재생 수10,178
# 좋아요 수18
# ==================================================
# === [[ 58 위 ]] ===================================
# 제목 장민호 - 사는 게 그런 거지 | THE 트롯SHOW 210830
# 채널명 더트롯쇼
# 재생 수30,016
# 좋아요 수3,027
# ==================================================
# === [[ 59 위 ]] ===================================
# 제목 [이 시각 세계] 흑마술 믿은 인니 부부…6살 딸 눈 훼손하다 체포
# 채널명 MBC뉴스
# 재생 수7,824
# 좋아요 수1
# ==================================================
# === [[ 60 위 ]] ===================================
# 제목 [3회] 세컨드 계급 댄스 비디오 (Choreo by 라치카 리안) @계급 미션 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수43,554
# 좋아요 수248
# ==================================================
# === [[ 61 위 ]] ===================================
# 제목 [3회] (워스트 댄서만 되지 말자..ㅠㅠ) 원트의 견제에 지지않고 맞서는 YGX! | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수38,980
# 좋아요 수167
# ==================================================
# === [[ 62 위 ]] ===================================
# 제목 [3회] 유리한 파트를 선점하기 위한 웨이비 vs 프라우드먼의 양보 없는 전쟁 | Mnet 210907 방송
# 채널명 스트릿 우먼 파이터
# 재생 수42,005
# 좋아요 수149
# ==================================================
# === [[ 63 위 ]] ===================================
# 제목 [3회/풀캠] 서브 계급 댄스 비디오 | 원트 모아나&엠마 메인 댄서 캠 @계급 미션
# 채널명 스트릿 우먼 파이터
# 재생 수10,925
# 좋아요 수70
# ==================================================
# === [[ 64 위 ]] ===================================
# 제목 [전체HL] '안치홍 결승타+투수진 호투' 롯데, 삼성에 승리
# 채널명 KBO리그 삼성 홈경기 영상
# 재생 수42,793
# 좋아요 수415
# ==================================================
# === [[ 65 위 ]] ===================================
# 제목 캠퍼스 벤치 가득 찬 쓰레기들…남몰래 치운 사람은?
# 채널명 SBS뉴스
# 재생 수4,126
# 좋아요 수6
# ==================================================
# === [[ 66 위 ]] ===================================
# 제목 미얀마 민주진영, 군부에 전쟁 선포...내전 신호탄
# 채널명 뉴스는 YTN
# 재생 수10,080
# 좋아요 수13
# ==================================================
# === [[ 67 위 ]] ===================================
# 제목 안효섭×김유정, 서로를 향한 두 남녀의 그리운 마음!
# 채널명 홍천기
# 재생 수20,502
# 좋아요 수210
# ==================================================
# === [[ 68 위 ]] ===================================
# 제목 이스라엘판 '쇼생크 탈출'…숟가락으로 구멍 뚫어 탈옥
# 채널명 SBS뉴스
# 재생 수4,626
# 좋아요 수1
# ==================================================
# === [[ 69 위 ]] ===================================
# 제목 장현성, 공명에 선왕 어용 복원 위한 화공을 찾으라는 왕의 지시 전달!
# 채널명 홍천기
# 재생 수14,668
# 좋아요 수73
# ==================================================
# === [[ 70 위 ]] ===================================
# 제목 [월드컵 유럽 예선] '연계왕!' 아트사커 만드는 벤제마
# 채널명 SPOTV
# 재생 수10,688
# 좋아요 수38
# ==================================================
# === [[ 71 위 ]] ===================================
# 제목 엘살바도르, 비트코인 공식 통용…국민 75%는 '반대'｜아침& 세계
# 채널명 JTBC뉴스
# 재생 수2,201
# 좋아요 수4
# ==================================================
# === [[ 72 위 ]] ===================================
# 제목 [3회/풀캠] 어시스트 계급 댄스 비디오 @계급 미션 Full Cam
# 채널명 스트릿 우먼 파이터
# 재생 수9,512
# 좋아요 수29
# ==================================================
# === [[ 73 위 ]] ===================================
# 제목 응급처치 쉬워지도록…'더 커지는' 119구급차 타보니
# 채널명 JTBC뉴스
# 재생 수11,475
# 좋아요 수37
# ==================================================
# === [[ 74 위 ]] ===================================
# 제목 '가세연' 강용석·김세의·김용호 체포…"10번 출석 통보 불응"
# 채널명 MBN 뉴스
# 재생 수5,303
# 좋아요 수7
# ==================================================
# === [[ 75 위 ]] ===================================
# 제목 가을장마 끝나지도 않았는데…13·14호 태풍 연달아 발생
# 채널명 SBS뉴스
# 재생 수5,009
# 좋아요 수4
# ==================================================
# === [[ 76 위 ]] ===================================
# 제목 [선공개] 특전사 최영재의 육아 일상, 딸들과 모닝 뽀뽀로 하루 시작❤️
# 채널명 해방타운
# 재생 수9,899
# 좋아요 수82
# ==================================================
# === [[ 77 위 ]] ===================================
# 제목 [월드컵 유럽 예선] 네덜란드 vs 터키 MVP 데파이
# 채널명 SPOTV
# 재생 수6,560
# 좋아요 수16
# ==================================================
# === [[ 78 위 ]] ===================================
# 제목 홍삼 스틱 비교해보니…"비싸다고 유효 함량 높지 않아"
# 채널명 MBC뉴스
# 재생 수9,856
# 좋아요 수7
# ==================================================
# === [[ 79 위 ]] ===================================
# 제목 곽시양, 마왕 찾기 위한 살벌한 의지♨
# 채널명 홍천기
# 재생 수15,174
# 좋아요 수70
# ==================================================
# === [[ 80 위 ]] ===================================
# 제목 [3회/풀캠] 세컨드 계급 댄스 비디오 @계급 미션 Full Cam
# 채널명 스트릿 우먼 파이터
# 재생 수9,060
# 좋아요 수44
# ==================================================
# === [[ 81 위 ]] ===================================
# 제목 "기초수급자도 지원금서 빠졌다"…건보료 기준 혼선
# 채널명 SBS뉴스
# 재생 수25,917
# 좋아요 수7
# ==================================================
# === [[ 82 위 ]] ===================================
# 제목 [앵커리포트] 김웅 "제보자 세력 알게 될 것"...野 대선판 흔드나?
# 채널명 뉴스는 YTN
# 재생 수11,013
# 좋아요 수2
# ==================================================
# === [[ 83 위 ]] ===================================
# 제목 도심 속 무허가 개 농장...잔혹한 도살까지
# 채널명 뉴스는 YTN
# 재생 수7,396
# 좋아요 수4
# ==================================================
# === [[ 84 위 ]] ===================================
# 제목 [4회 선공개] “아니 저 여인은..” 김유정에게 달려가는 공명! 이를 지켜보는 안효섭♥
# 채널명 홍천기
# 재생 수121,281
# 좋아요 수1,173
# ==================================================
# === [[ 85 위 ]] ===================================
# 제목 신곡무대☆ 이찬원 ‘편의점’♬ 24시간 언제든지 많관부😆 TV CHOSUN 210902 방송
# 채널명 사랑의 콜센타
# 재생 수48,570
# 좋아요 수9,592
# ==================================================
# === [[ 86 위 ]] ===================================
# 제목 전설도 감동한 순수 보이스 ‘잊어야한다는 마음으로’♪ TV CHOSUN 210902 방송
# 채널명 사랑의 콜센타
# 재생 수41,324
# 좋아요 수3,873
# ==================================================
# === [[ 87 위 ]] ===================================
# 제목 [선공개] 남편 살인자 조여정, 남편과 요트 안 뜨거운 밤♥ (♨베드신♨)
# 채널명 하이클래스
# 재생 수168,468
# 좋아요 수216
# ==================================================
# === [[ 88 위 ]] ===================================
# 제목 2화#하이라이트# 국제학교 학부모들의 텃세 피해 단짝 친구된 조여정X박세진
# 채널명 하이클래스
# 재생 수5,707
# 좋아요 수9
# ==================================================
# === [[ 89 위 ]] ===================================
# 제목 김유정, 가마 보며 생각난 안효섭에 그리움 가득
# 채널명 홍천기
# 재생 수15,495
# 좋아요 수169
# ==================================================
# === [[ 90 위 ]] ===================================
# 제목 '메이저 퀸' 박현경이 직접 말한 스윙비법 [박현경의 스윙레슨]
# 채널명 ETgolf
# 재생 수17,428
# 좋아요 수97
# ==================================================
# === [[ 91 위 ]] ===================================
# 제목 이번엔 반드시 살인을 막아야 한다 [블루버스데이] - EP.14
# 채널명 플레이리스트 오리지널 PLAYLIST ORIGINALS
# 재생 수227,874
# 좋아요 수3,004
# ==================================================
# === [[ 92 위 ]] ===================================
# 제목 [3화 예고] ＂사실대로 말 해!＂ 조여정 공격에 밀리는 김지수x공현주?!
# 채널명 하이클래스
# 재생 수10,078
# 좋아요 수18
# ==================================================
# === [[ 93 위 ]] ===================================
# 제목 문숙, 김유정으로부터 안효섭에 갇힌 마왕 영원히 봉인되길 기원!
# 채널명 홍천기
# 재생 수58,219
# 좋아요 수249
# ==================================================
# === [[ 94 위 ]] ===================================
# 제목 [3회/풀캠] 세컨드 계급 댄스 비디오 | 라치카 리안 메인 댄서 캠 @계급 미션
# 채널명 스트릿 우먼 파이터
# 재생 수7,396
# 좋아요 수44
# ==================================================
# === [[ 95 위 ]] ===================================
# 제목 [3회/풀캠] 서브 계급 댄스 비디오 @계급 미션 Full Cam
# 채널명 스트릿 우먼 파이터
# 재생 수8,223
# 좋아요 수36
# ==================================================
# === [[ 96 위 ]] ===================================
# 제목 [날씨] 비 찔끔 차츰 그쳐…서쪽부터 맑은 하늘
# 채널명 MBC뉴스
# 재생 수6,182
# 좋아요 수7
# ==================================================
# === [[ 97 위 ]] ===================================
# 제목 [재택플러스] 로봇 경쟁에 뛰어든 자동차 회사
# 채널명 MBC뉴스
# 재생 수2,519
# 좋아요 수7
# ==================================================
# === [[ 98 위 ]] ===================================
# 제목 김유정, 그림 경연 대회 '화회' 나가기 위한 필사의 의지!
# 채널명 홍천기
# 재생 수12,001
# 좋아요 수106
# ==================================================
# === [[ 99 위 ]] ===================================
# 제목 김유정, 화회 출전 반대하는 김광규에 서운!
# 채널명 홍천기
# 재생 수11,717
# 좋아요 수97
# ==================================================
# === [[ 100 위 ]] ===================================
# 제목 [3회/풀캠] 어시스트 계급 댄스 비디오 | 프라우드먼 헤일리 메인 댄서 캠 @계급 미션
# 채널명 스트릿 우먼 파이터
# 재생 수7,875
# 좋아요 수19
# ==================================================
