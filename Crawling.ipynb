# %% [markdown]
# # 1. 네이버 티비 : 영상 제목, 채널, 조회수, 좋아요 수

# %% [markdown]
# ## 1-1. 컨테이너 수집

# %%
import requests
from bs4 import BeautifulSoup as bs
#from urllib.request import urlopen

# 소스코드 가져오기

# raw
raw = requests.get("https://tv.naver.com/r")
print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
print(raw.elapsed)
#print(raw.text) # 그저 txt

# 파싱하기
html = bs(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 컨테이너
clips = html.select("div.inner")
clips
#print(clips[0])
# Out:
# <Response [200]>
# 0:00:00.071287
# [<div class="inner">
#  <a class="box" data-anisrc="https://phinf.pstatic.net/tvcast/20210908_126/IhyFE_1631073610783UIsyr_GIF/410a98df-1059-11ec-a642-b496915e8754.gif?type=mfullfill_406_228_ani_limit15" href="https://tv.naver.com/v/22330032/list/67096" onclick="clickcr(this, 'top.3clip', '', '1', event)">
#  <span class="mask _top_ani_area"></span>
#  <img alt="대한민국-레바논 하이라이트" data-src="https://phinf.pstatic.net/tvcast/20210908_265/ou26q_1631067796163jMdvC_JPEG/%C7%CF%B6%F3.jpg?type=f406_228_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"' src="https://phinf.pstatic.net/tvcast/20210908_265/ou26q_1631067796163jMdvC_JPEG/%C7%CF%B6%F3.jpg?type=f406_228_blend"/>
#  <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0"/>
# ...

# %% [markdown]
# ## 1-2. 컨테이너 별 데이터 수집

# %%
import requests
from bs4 import BeautifulSoup

# 소스코드 가져오기
raw = requests.get("https://tv.naver.com/r")
print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
print(raw.elapsed)
#print(raw.text) # 그저 txt

#파싱하기
html = BeautifulSoup(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

#컨테이너
clips = html.select("div.inner") # select 함수는 BS4안에 포함된 함수, html로 파싱한 코드가 있는 변수에 사용
#print(clips[0])

# 데이터 찾기
title = clips[0].select_one("dt.title") 
chn = clips[0].select_one("dd.chn")
hit = clips[0].select_one("span.hit")
like = clips[0].select_one("span.like")

print(title)
print(title.text) # 텍스트만 출력
print(chn)
print(chn.text)
print(hit)
print(hit.text)
print(like.text)
# Out:
# <Response [200]>
# 0:00:00.073549
# <dt class="title">
# <a href="https://tv.naver.com/v/22303206" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# <strong class="tit"><span>[MLB] '6이닝 6K 무사사구 무실점' 류현진 투구 모음</span></strong>
# </a>
# </dt>
#
#
# [MLB] '6이닝 6K 무사사구 무실점' 류현진 투구 모음
#
#
# <dd class="chn">
# <a class="ch" href="https://tv.naver.com/spotvmlb" onclick="clickcr(this, 'top.3chtitle', '', '1', event)">SPOTV_MLB</a>
# </dd>
#
# SPOTV_MLB
#
# <span class="hit"><span class="blind">재생 수</span>443,703</span>
# 재생 수443,703
# 좋아요 수1,885

# %% [markdown]
# ## 1-3. 수집반복

# %%
import requests
from bs4 import BeautifulSoup

# 소스코드 가져오기
raw = requests.get("https://tv.naver.com/r")
print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
print(raw.elapsed)
#print(raw.text) # 그저 txt

#파싱하기
html = BeautifulSoup(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 반복 수집


## 1~3위
n = 1

### 컨테이너
clips = html.select("div.inner") # select 함수는 BS4안에 포함된 함수, html로 파싱한 코드가 있는 변수에 사용, 1~3위
#print(clips[0])

for i in range(len(clips)) : # range() 활용
    print("=== [[", n, "위 ]]","="*35)
    title = clips[i].select_one("dt.title") # select 함수는 BS4안에 포함된 함수, html로 파싱한 코드가 있는 변수에 사용
    chn = clips[i].select_one("dd.chn")
    hit = clips[i].select_one("span.hit")
    like = clips[i].select_one("span.like")

    #print(title)
    print(title.text.strip()) # 텍스트만 출력
    #print(chn)
    print(chn.text.strip())
    #print(hit)
    print(hit.text.strip())
    print(like.text.strip())
    print("="*50)
    n = n + 1


## 4~100위

### 컨테이너
clips = html.select("div.cds") # 4~100위

for cl in clips: # 리스트 >> clips = [...]
    print("=== [[", n, "위 ]]","="*35)
    
    title = cl.select_one("dt.title")
    chn = cl.select_one("dd.chn")
    hit = cl.select_one("span.hit")
    like = cl.select_one("span.like")

    print("제목", title.text.strip())
    print("채널명", chn.text.strip())
    print(hit.text.strip())
    print(like.text.strip())
    print("="*50)
    n = n + 1
# Out:
# <Response [200]>
# 0:00:00.070466
# === [[ 1 위 ]] ===================================
# 임영웅X설운도 ‘별빛 같은 나의 사랑아’♬ 이 조합 영원하길..❤ TV CHOSUN 210902 방송
# 사랑의 콜센타
# 재생 수111,852
# 좋아요 수18,171
# ...
# === [[ 2 위 ]] ===================================
# 남자 특집에 딱!이야 ‘My Way’♪ 브라보 김호중👏
# 사랑의 콜센타
# 재생 수562,715
# 좋아요 수27,106
# ...
# === [[ 3 위 ]] ===================================
# [MLB] '6이닝 6K 무사사구 무실점' 류현진 투구 모음
# SPOTV_MLB
# 재생 수474,574
# 좋아요 수2,022
# ...
# === [[ 4 위 ]] ===================================
# 제목 [4회 선공개] “아니 저 여인은..” 김유정에게 달려가는 공명! 이를 지켜보는 안효섭♥
# 채널명 홍천기
# 재생 수67,768
# 좋아요 수764
# ...
# === [[ 5 위 ]] ===================================
# 제목 [메이킹] 단태-윤철의 마지막 순간 비하인드! 연기 좀 다들 살살해주시겠어요..? (ft.설탕이)
# 채널명 펜트하우스 3
# 재생 수10,094
# 좋아요 수168
# ...
# === [[ 6 위 ]] ===================================
# 제목 [3회 선공개] 리더 계급 댄스 비디오 | 웨이비 노제 메인 댄서 캠 @계급 미션
# 채널명 스트릿 우먼 파이터
# 재생 수39,062
# 좋아요 수178
# ...
# === [[ 7 위 ]] ===================================
# 제목 [단독선공개] 조여정 노골적으로 견제하는 국제학교 맘들
# 채널명 하이클래스
# 재생 수40,372
# 좋아요 수101
# ...

# %% [markdown]
# # 2. 네이버 뉴스 : 제목, 출처

# %% [markdown]
# ## 2-1. 컨테이너 수집

# %%
import requests
from bs4 import BeautifulSoup as bs
#from urllib.request import urlopen

# 소스코드 가져오기

## raw
raw = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=코로나", 
                  headers={"User-Agent" : "Chrome/51.0.2704.103"}) # 주소, header를 사용  >> 웹브라우저에 대한 데이터를 같이 전송
#print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
#print(raw.elapsed)
#print(raw.text) # 그저 txt

# 파싱하기
html = BeautifulSoup(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 컨테이너
articles = html.select("ul.list_news > li") # <ul class="list_news"> <li class="bx" id="sp_nws1"> ... </li> ... </ul>
print(articles[0]) # 첫 번째 기사
# Out:
# <li class="bx" id="sp_nws1"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="http://www.fnnews.com/news/202109071019564630" href="#" onclick="tCR('a=nws*h.kep&amp;r=1&amp;i=880000FF_000000000000000004704672&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*h.kepoff&amp;r=1&amp;i=880000FF_000000000000000004704672&amp;u=javascript" data-cr-on="a=nws*h.kepon&amp;r=1&amp;i=880000FF_000000000000000004704672&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*h.kephome&amp;r=1&amp;i=880000FF_000000000000000004704672&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div></div><div class
# ...

# %% [markdown]
# ## 2-2. 컨테이너 별 데이터 수집

# %%
import requests
from bs4 import BeautifulSoup as bs
#from urllib.request import urlopen

# 소스코드 가져오기

## raw
raw = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=코로나", 
                  headers={"User-Agent" : "Chrome/51.0.2704.103"}) # 주소, header를 사용  >> 웹브라우저에 대한 데이터를 같이 전송
#print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
#print(raw.elapsed)
#print(raw.text) # 그저 txt

# 파싱하기
html = BeautifulSoup(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 컨테이너
articles = html.select("ul.list_news > li") # <ul class="list_news"> <li class="bx" id="sp_nws1"> ... </li> ... </ul>
#print(articles[0]) # 첫 번째 기사

# 데이터 찾기
title = articles[0].select_one("a.news_tit")
print(title.text)
source = articles[0].select_one("a.info.press") # " " = "." : ??
print(source.text)
print(source.text[0:-6])
# Out:
# 코로나 국민지원금 신청 첫날 507만명에 1조2천666억원 지급
# 연합뉴스언론사 선정
# 연합뉴스

# %% [markdown]
# ## 2-3. 수집 반복

# %%
import requests
from bs4 import BeautifulSoup as bs
#from urllib.request import urlopen

# 소스코드 가져오기

## raw
raw = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=코로나", 
                  headers={"User-Agent" : "Chrome/51.0.2704.103"}) # 주소, header를 사용  >> 웹브라우저에 대한 데이터를 같이 전송
#print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
#print(raw.elapsed)
#print(raw.text) # 그저 txt

# 파싱하기
html = BeautifulSoup(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 컨테이너
articles = html.select("ul.list_news > li") # <ul class="list_news"> <li class="bx" id="sp_nws1"> ... </li> ... </ul>
#print(articles[0]) # 첫 번째 기사

# 수집 반복
for a in articles :
    title = a.select_one("a.news_tit").text
    source = a.select_one("a.info.press").text[0:-6]
    
    print(title, "-"*5, source)
# Out:
# [속보]文대통령, 코로나 의료진 등 1만5천명에 '추석 선물' ----- 파이낸셜뉴스
# 코로나 국민지원금 신청 첫날 507만명에 1조2천666억원 지급 ----- 연합뉴스
# 국민 10명 중 7명 "'위드 코로나' 전환 찬성…11월 말이 적당" ----- 연합뉴스
# ‘위드 코로나’ 전환, 시점 나왔다…정은경 “10월 말 가능” ----- 조선비즈
# 국민 10명 중 7명 "'위드 코로나' 전환 찬성…11월 말이 적당" ----- MBC
# KDI "코로나 확산·원자재값 상승에 경기 불확실성 확대" ----- 이데일리
# 코로나19 신규 확진자 1597명···월요일 역대 최다 ----- 경향신문
# 文대통령 "코로나로 더 중요해진 사회복지인들 인건비 현실화" ----- 노컷뉴스
# 코로나 신규확진 1597명… 월요일 기준 최다 ----- 조선비즈
# EMA, 화이자 코로나19 백신 부스터샷 권고 여부 검토 ----- 연합뉴스

# %% [markdown]
# ## 2-4. 여러 페이지에서 수집 반복

# %% [markdown]
# ### 2-4.1. 여러 페이지에서 수집 반복

# %%
import requests
from bs4 import BeautifulSoup as bs
#from urllib.request import urlopen

# 소스코드 가져오기

## raw

for i in range(1, 100, 10) :
    raw = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=코로나&start="+str(i), 
                      headers={"User-Agent" : "Chrome/51.0.2704.103"}) # 주소, header를 사용  >> 웹브라우저에 대한 데이터를 같이 전송
#print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
#print(raw.elapsed)
#print(raw.text) # 그저 txt

# 파싱하기
    html = BeautifulSoup(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 컨테이너
    articles = html.select("ul.list_news > li") # <ul class="list_news"> <li class="bx" id="sp_nws1"> ... </li> ... </ul>
#print(articles[0]) # 첫 번째 기사


    for a in articles :
        title = a.select_one("a.news_tit").text
        source = a.select_one("a.info.press").text[0:-6]
    
        print(title, "-"*5, source)
# Out:
# 코로나 국민지원금 신청 첫날 507만명에 1조2천666억원 지급 ----- 연합뉴스
# 국민 10명 중 7명 "'위드 코로나' 전환 찬성…11월 말이 적당" ----- 연합뉴스
# [속보]文대통령, 코로나 의료진 등 1만5천명에 '추석 선물' ----- 파이낸셜뉴스
# ‘위드 코로나’ 전환, 시점 나왔다…정은경 “10월 말 가능” ----- 조선비즈
# 국민 10명 중 7명 "'위드 코로나' 전환 찬성…11월 말이 적당" ----- MBC
# KDI "코로나 확산·원자재값 상승에 경기 불확실성 확대" ----- 이데일리
# 코로나19 신규 확진자 1597명···월요일 역대 최다 ----- 경향신문
# 文대통령 "코로나로 더 중요해진 사회복지인들 인건비 현실화" ----- 노컷뉴스
# [속보] "코로나19 백신 접종 예방효과 16∼18세 98.4%, 19∼24세 92.4%" ----- 부산일보
# 코로나 신규확진 1597명… 월요일 기준 최다 ----- 조선비즈
# 코로나19 신규 확진자 1597명···월요일 역대 최다 ----- 경향신문
# "10월초 '위드코로나' 조기 전환, 찬성 58.5% 반대 34.3%" ----- 연합뉴스
# [Q&A] 독감-코로나19 백신 같이 맞을 땐…"접종간격 제한 없어" ----- 연합뉴스
# 文대통령 "코로나로 더 중요해진 사회복지인들 인건비 현실화" ----- 노컷뉴스
# [속보] "코로나19 백신 접종 예방효과 16∼18세 98.4%, 19∼24세 92.4%" ----- 부산일보
# 제주 초등학생 '학폭' 피해 1.7%p↑…코로나19가 키웠다 ----- 파이낸셜뉴스
# 독감백신 1천460만명에 무료접종…코로나19 예방접종과 동시 진행 ----- 연합뉴스
# 문 대통령 부부, 코로나 의료진 등 1만 5천여 명에게 추석 선물 ----- MBC
# "네이버·카카오맵서 코로나 국민지원금 사용처 확인하세요"(종합) ----- 연합뉴스
# 문대통령 "새 방역체계 모색"…위드코로나 속도 내나(종합) ----- 연합뉴스
# ...

# %% [markdown]
# ### 2-4.2. 여러 페이지에서 수집 반복 2 : 언론사선정 태그가 없는 경우 출처 출력 오류 수정

# %%
import requests
from bs4 import BeautifulSoup as bs
#from urllib.request import urlopen

# 소스코드 가져오기

## raw

for i in range(1, 100, 10) : # 반복문 사용 > 여러 페이지 주소 획득
    raw = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=코로나&start="+str(i), 
                      headers={"User-Agent" : "Chrome/51.0.2704.103"}) # 주소, header를 사용  >> 웹브라우저에 대한 데이터를 같이 전송
#print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
#print(raw.elapsed)
#print(raw.text) # 그저 txt

# 파싱하기
    html = BeautifulSoup(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 컨테이너
    articles = html.select("ul.list_news > li") # <ul class="list_news"> <li class="bx" id="sp_nws1"> ... </li> ... </ul>
#print(articles[0]) # 첫 번째 기사
# 반복 수집

    for a in articles :
        title = a.select_one("a.news_tit").text
        source = a.select_one("a.info.press").text
        if source.startswith("언론사 선정", source.find("언론사 선정")) :
            source = a.select_one("a.info.press").text[0:-6]

        print(title, "-"*5, source)
# Out:
# 코로나 국민지원금 신청 첫날 507만명에 1조2천666억원 지급 ----- 연합뉴스
# 국민 10명 중 7명 "'위드 코로나' 전환 찬성…11월 말이 적당" ----- 연합뉴스
# [속보]文대통령, 코로나 의료진 등 1만5천명에 '추석 선물' ----- 파이낸셜뉴스
# ‘위드 코로나’ 전환, 시점 나왔다…정은경 “10월 말 가능” ----- 조선비즈
# 국민 10명 중 7명 "'위드 코로나' 전환 찬성…11월 말이 적당" ----- MBC
# KDI "코로나 확산·원자재값 상승에 경기 불확실성 확대" ----- 이데일리
# 코로나19 신규 확진자 1597명···월요일 역대 최다 ----- 경향신문
# 文대통령 "코로나로 더 중요해진 사회복지인들 인건비 현실화" ----- 노컷뉴스
# [속보] "코로나19 백신 접종 예방효과 16∼18세 98.4%, 19∼24세 92.4%" ----- 부산일보
# 코로나 신규확진 1597명… 월요일 기준 최다 ----- 조선비즈
# 코로나19 신규 확진자 1597명···월요일 역대 최다 ----- 경향신문
# "10월초 '위드코로나' 조기 전환, 찬성 58.5% 반대 34.3%" ----- 연합뉴스
# 제주 초등학생 '학폭' 피해 1.7%p↑…코로나19가 키웠다 ----- 파이낸셜뉴스
# [Q&A] 독감-코로나19 백신 같이 맞을 땐…"접종간격 제한 없어" ----- 연합뉴스
# 文대통령 "코로나로 더 중요해진 사회복지인들 인건비 현실화" ----- 노컷뉴스
# [속보] "코로나19 백신 접종 예방효과 16∼18세 98.4%, 19∼24세 92.4%" ----- 부산일보
# 독감백신 1천460만명에 무료접종…코로나19 예방접종과 동시 진행 ----- 연합뉴스
# 문 대통령 부부, 코로나 의료진 등 1만 5천여 명에게 추석 선물 ----- MBC
# "네이버·카카오맵서 코로나 국민지원금 사용처 확인하세요"(종합) ----- 연합뉴스
# 문대통령 "새 방역체계 모색"…위드코로나 속도 내나(종합) ----- 연합뉴스
# ...

# %% [markdown]
# # 3. 수집한 데이터 csv 파일로 저장하기

# %% [markdown]
# ## 3.1. 메모장 작성하기

# %%
f = open("test.txt", "w") # "w": write 모드, "r":read 모드, "a": append 모드(이미 존재하는 파일에 내용 이어쓸 때)

f.write("hello world! \n")
f.write("good bye")

f.close()

# %% [markdown]
# ## 3-1. csv 파일 만들기

# %%
f = open("test1.csv", "w", encoding = "UTF-8") # "w": write 모드, "r":read 모드, "a": append 모드(이미 존재하는 파일에 내용 이어쓸 때)

names = ["반준석", "김유진", "정민지"]
nick_n = ["삼촌", "K-유진", "K-minz"]
for i in range(len(names)):
    f.write(names[i] + "," + nick_n[i])

f.close()

# %%
f = open("hitsong.csv", "w")

singers = ["박정현", "임창정", "izi", "아이유"]
songs = ["꿈에", "소주한잔", "응급실", "좋은날"]
for i in range(len(singers)):
    f.write(singers[i] + ',' + songs[i] + '\n')

f.close()

# %% [markdown]
# ## 3-2. 네이버TV 수집 데이터 csv파일로 저장하기

# %% [markdown]
# ## 3-3. 뉴스 수집 데이터 csv파일로 저장하기

# %% [markdown]
# ### 3-3.1. csv 파일로 저장

# %%
import requests
from bs4 import BeautifulSoup as bs
#from urllib.request import urlopen


# naver_news.csv파일을 write 모드로 열기
f = open("naver_news.csv", "w", encoding = "UTF-8")
# 헤더 추가하기 (첫 줄 할당?)
f.write("제목, 출처\n")

# 소스코드 가져오기

## raw
for i in range(1, 100, 10) : # 반복문 사용 > 여러 페이지 주소 획득
    raw = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=코로나&start="+str(i), 
                      headers={"User-Agent" : "Chrome/51.0.2704.103"}) # 주소, header를 사용  >> 웹브라우저에 대한 데이터를 같이 전송
#print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
#print(raw.elapsed)
#print(raw.text) # 그저 txt

# 파싱하기
    html = bs(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 컨테이너
    articles = html.select("ul.list_news > li") # <ul class="list_news"> <li class="bx" id="sp_nws1"> ... </li> ... </ul>
#print(articles[0]) # 첫 번째 기사

# 반복 수집
    for a in articles :
        title = a.select_one("a.news_tit").text
        source = a.select_one("a.info.press").text
        if source.startswith("언론사 선정", source.find("언론사 선정")) :
            source = a.select_one("a.info.press").text[0:-6]

        print(title, "-"*5, source)
        
        # 파일에 내용 입력
        f.write(title + "," + source + "\n")
        
f.close()
# Out:
# 정은경 "위드 코로나, 10월말이면 검토 가능할 것" ----- 연합뉴스
# 정은경 "10월 말부터 위드 코로나 적용"…당국, 국민 10명 중 7명 "찬성" ----- 강원일보
# 코로나 신규확진 1597명… 월요일 기준 최다 ----- 조선비즈
# 어제 코로나19 신규 확진 2050명…일주일 만에 다시 2000명대 ----- 세계일보
# [속보] 코로나19 신규 확진자 2,050명…1차 접종률 61% ----- KBS
# 제주 초등학생 '학폭' 피해 1.7%p↑…코로나19가 키웠다 ----- 파이낸셜뉴스
# EMA, 화이자 코로나19 백신 부스터샷 권고 여부 검토 ----- 연합뉴스
# [단독]코로나로 필수 비행 횟수 못 채워···아시아나 A380 조종사 120명 자... ----- 경향신문
# 문 대통령 부부, 코로나 의료진 등 1만 5천여 명에게 추석 선물 ----- MBC
# 코로나19 국민지원금 신청 첫날 1조 2666억 원 지급 ----- 노컷뉴스
# 英총리, 코로나 대응 세금 인상 발표 ----- 파이낸셜뉴스
# 코로나19 백신 1차 접종자 전 국민 60% 돌파 ----- 파이낸셜뉴스
# 문 대통령 부부, 코로나 의료진 등 1만 5천여 명에게 추석 선물 ----- MBC
# 코로나19 국민지원금 신청 첫날 1조 2666억 원 지급 ----- 노컷뉴스
# KDI "코로나 확산·원자재값 상승에 경기 불확실성 확대" ----- 이데일리
# WHO "코로나, 인플루엔자처럼 변이해 계속 나타날 것" ----- 연합뉴스
# 국민 4명 중 1명 백신에 부정적…위드 코로나 최대 복병 ----- 뉴스1
# 제주 초등학생 '학폭' 피해 1.7%p↑…코로나19가 키웠다 ----- 파이낸셜뉴스
# [속보]文대통령, 코로나 의료진 등 1만5천명에 '추석 선물' ----- 파이낸셜뉴스
# [Y이슈] 코로나19 여파 없다...MAMA 팬데믹 속 2년 연속 개최 ----- YTN
# '코로나 종식 기원' ----- 뉴시스
# ...

# %% [markdown]
# ### 3-3.2. csv 파일로 저장 2 : 원본 값에서 ','값을 제거 >> ','를 구분으로 값을 저장하기 때문

# %%
import requests
from bs4 import BeautifulSoup as bs
#from urllib.request import urlopen


# naver_news.csv파일을 write 모드로 열기
f = open("naver_news.csv", "w", encoding = "UTF-8")
# 헤더 추가하기 (첫 줄 할당?)
f.write("제목, 출처\n")

# 소스코드 가져오기

## raw
for i in range(1, 100, 10) : # 반복문 사용 > 여러 페이지 주소 획득
    raw = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=코로나&start="+str(i), 
                      headers={"User-Agent" : "Chrome/51.0.2704.103"}) # 주소, header를 사용  >> 웹브라우저에 대한 데이터를 같이 전송
#print(raw) # Response = 200 : 정상 / 404 : 'Page not found'
#print(raw.elapsed)
#print(raw.text) # 그저 txt

# 파싱하기
    html = bs(raw.text, "html.parser") # raw.txt를 html로 파싱 >> html 태깅된 코드
#print(html)

# 컨테이너
    articles = html.select("ul.list_news > li") # <ul class="list_news"> <li class="bx" id="sp_nws1"> ... </li> ... </ul>
#print(articles[0]) # 첫 번째 기사

# 반복 수집
    for a in articles :
        title = a.select_one("a.news_tit").text
        source = a.select_one("a.info.press").text
        if source.startswith("언론사 선정", source.find("언론사 선정")) :
            source = a.select_one("a.info.press").text[0:-6]

        # replace 함수를 사용하여 ',' 제거
        title = title.replace(",", "")
        source = source.replace(",", "")
        
        
        print(title, "-"*5, source)
        
        # 파일에 내용 입력
        f.write(title + "," + source + "\n")
        
f.close()
# Out:
# 정은경 "위드 코로나 10월말이면 검토 가능할 것" ----- 연합뉴스
# 정은경 "10월 말부터 위드 코로나 적용"…당국 국민 10명 중 7명 "찬성" ----- 강원일보
# 코로나 신규확진 1597명… 월요일 기준 최다 ----- 조선비즈
# 어제 코로나19 신규 확진 2050명…일주일 만에 다시 2000명대 ----- 세계일보
# [속보] 코로나19 신규 확진자 2050명…1차 접종률 61% ----- KBS
# 제주 초등학생 '학폭' 피해 1.7%p↑…코로나19가 키웠다 ----- 파이낸셜뉴스
# EMA 화이자 코로나19 백신 부스터샷 권고 여부 검토 ----- 연합뉴스
# [단독]코로나로 필수 비행 횟수 못 채워···아시아나 A380 조종사 120명 자... ----- 경향신문
# 문 대통령 부부 코로나 의료진 등 1만 5천여 명에게 추석 선물 ----- MBC
# 코로나19 국민지원금 신청 첫날 1조 2666억 원 지급 ----- 노컷뉴스
# 英총리 코로나 대응 세금 인상 발표 ----- 파이낸셜뉴스
# 코로나19 백신 1차 접종자 전 국민 60% 돌파 ----- 파이낸셜뉴스
# 문 대통령 부부 코로나 의료진 등 1만 5천여 명에게 추석 선물 ----- MBC
# 코로나19 국민지원금 신청 첫날 1조 2666억 원 지급 ----- 노컷뉴스
# KDI "코로나 확산·원자재값 상승에 경기 불확실성 확대" ----- 이데일리
# WHO "코로나 인플루엔자처럼 변이해 계속 나타날 것" ----- 연합뉴스
# 국민 4명 중 1명 백신에 부정적…위드 코로나 최대 복병 ----- 뉴스1
# 제주 초등학생 '학폭' 피해 1.7%p↑…코로나19가 키웠다 ----- 파이낸셜뉴스
# [속보]文대통령 코로나 의료진 등 1만5천명에 '추석 선물' ----- 파이낸셜뉴스
# [Y이슈] 코로나19 여파 없다...MAMA 팬데믹 속 2년 연속 개최 ----- YTN
# '코로나 종식 기원' ----- 뉴시스
# ...

# %% [markdown]
# # 4. 수집한 데이터 엑셀 파일로 저장하기

# %% [markdown]
# ## 4.1. 엑셀 파일 만들기

# %% [markdown]
# ### 4.1-0. 엑셀 파일 작성하기

# %%
import openpyxl

# 워크북(엑셀파일) 새로 만들기
wb = openpyxl.Workbook()

# 워크북을 원하는 이름으로 저장
wb.save("test.xlsx")

# %% [markdown]
# ### 4.1-1. 시트 선택하기 / 데이터 쓰기

# %%
import openpyxl

# 워크북(엑셀파일) 새로 만들기
wb = openpyxl.Workbook()

# 현재 활성화된 시트 선택
sheet = wb.active

# A1셀에 hello world!를 입력
sheet["A1"] = "hello world!"

# 워크북을 원하는 이름으로 저장
wb.save("test.xlsx")

# %% [markdown]
# ### 4.1-2. 숫자로 데이터 입력하기

# %%
import openpyxl

# 워크북(엑셀파일) 새로 만들기
wb = openpyxl.Workbook()

# 현재 활성화된 시트 선택
sheet = wb.active

# A1셀에 hello world!를 입력
sheet["A1"] = "hello world!"

# .cell(row = m, column = n).value로 m행 n열에 데이터 입력 가능
sheet.cell(row = 3, column = 3).value = "BYE !!" # 정확한 셀번호를 알지 못하면 입력이 어렵고 반복작업이 용이하지 않음.. 

# 워크북을 원하는 이름으로 저장
wb.save("test.xlsx")

# %% [markdown]
# ### 4.1-3. 가장 마지막 줄에 데이터 입력하기

# %%
import openpyxl

# 워크북(엑셀파일) 새로 만들기
wb = openpyxl.Workbook()

# 현재 활성화된 시트 선택
sheet = wb.active

# A1셀에 hello world!를 입력
sheet["A1"] = "hello world!"

# .cell(row = m, column = n).value로 m행 n열에 데이터 입력 가능
sheet.cell(row = 3, column = 3).value = "BYE !!" # 정확한 셀번호를 알지 못하면 입력이 어렵고 반복작업이 용이하지 않음.. 

# .append(리스트) : 시트의 데이터가 없는 가장 첫 줄에 데이터가 리스트 값의 구분에 따라 열이 구분되어 입력
subject = ["Python", "Java", "HTML", "JavaScript"]
sheet.append(subject)

# 워크북을 원하는 이름으로 저장
wb.save("test.xlsx")

# %% [markdown]
# ### 4.1-4. 시트 이름 변경, 새로운 시트 생성

# %%
import openpyxl

# 워크북(엑셀파일) 새로 만들기
wb = openpyxl.Workbook()

# sheet1을 현재 활성화된 시트로 선택
sheet1 = wb.active

# sheet1의 이름 변경
sheet1.title = "for row"

# 새로운 시트 만들고 sheet2로 저장
sheet2 = wb.create_sheet("for column")

# 첫 번째 시트와 두 번째 시트 동시에 데이터 쓰기
for i in range(1, 10) :
    sheet1.cell(row = i, column = 1).value = i # 행마다
    sheet2.cell(row = 1, column = i).value = i # 열마다
    
# 워크북을 원하는 이름으로 저장
wb.save("test2.xlsx")

# %% [markdown]
# ## 4-1. 뉴스 수집 데이터 엑셀 파일로 저장하기

# %% [markdown]
# # 5. 이미지 데이터 수집

# %% [markdown]
# ## 이미지 데이터 저장하기

# %%
from urllib.request import urlretrieve

urlretrieve("https://movie-phinf.pstatic.net/20210903_120/1630637262749GjJyG_JPEG/movie_image.jpg", "007.jpg")
# Out:
# ('007.jpg', <http.client.HTTPMessage at 0x25a83e8fb50>)

# %%
from urllib.request import urlretrieve

# urlretrieve 에러 발생시 추가
import ssl
ssl._create_default_https_context = ssl._create_unverified_context # 보안을 회피하여 다운로드

urlretrieve("https://movie-phinf.pstatic.net/20210903_120/1630637262749GjJyG_JPEG/movie_image.jpg", "007.jpg")
# Out:
# ('007.jpg', <http.client.HTTPMessage at 0x25a83e8f0a0>)

# %% [markdown]
# ## 데이터 수집기를 통해 이미지 데이터 저장하기

# %%
import requests
from bs4 import BeautifulSoup as bs

# 웹페이지에서 소스코드를 가져와 BeautifulSoup으로 파싱
raw = requests.get("https://movie.naver.com/movie/running/current.naver", 
                   headers={"User-Agent" : "Chrome/51.0.2704.103"})
html = bs(raw.text, 'html.parser')

# 컨테이너 수집하기
movie = html.select("dl.lst_dsc")
for m in movie:
    title = m.select_one("dt.tit a”)
    print("="*50)
    print("제목:", title.text)

    url = "https://movie.naver.com" + title.attrs["href"]
    # print(url)
    
    # url(상세페이지)에 접속, html 파싱
    raw_each = requests.get(url, headers={"User-Agent":"Mozilla/5.0"})
    html_each = BeautifiulSoup(raw_each.text, 'html.parser')

# %%
import requests
from bs4 import BeautifulSoup as bs
import ssl

ssl._create_default_https_context = ssl._create_unverified_context # 보안을 회피하여 다운로드

# 웹페이지에서 소스코드를 가져와 BeautifulSoup으로 파싱
raw = requests.get("https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EC%82%AC%EA%B3%BC", 
                   headers={"User-Agent" : "Chrome/51.0.2704.103"})
html = bs(raw.text, 'html.parser')

# 컨테이너 수집하기
image = html.select("div.cont_tab")
image
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup as bs
import ssl

ssl._create_default_https_context = ssl._create_unverified_context # 보안을 회피하여 다운로드

# 웹페이지에서 소스코드를 가져와 BeautifulSoup으로 파싱
raw = requests.get("https://search.daum.net/search?nil_suggest=btn&w=img&DA=SBC&q=%EB%88%84%EC%9A%B4+%EC%9E%90%EC%84%B8", 
                   headers={"User-Agent" : "Chrome/51.0.2704.103"})
html = bs(raw.text, 'html.parser')

# 컨테이너 수집하기
image = html.select("div.coll_cont > div")
image
# Out:
# [<div class="cont_img cont_tab" id="imgList"> </div>]

# %% [markdown]
# # 이미지 수집

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
#from urllib.parse import quote_plus

# 소스
base_url = "https://search.naver.com/search.naver?where=image&sm=tab_jum&query=" # 네이버 검색url
search_url = "아이유" #input("검색어를 입력하세요 : ") # 검색어 질문
#url = base_url + search_url
url = base_url + quote_plus(search_url) # quote_plus를 사용해 쿼리 문자열 만들기
print(url)

# raw
#keyword = "아이유" #input("검색어를 입력하세요 : ")
#raw = requests.get("https://search.naver.com/search.naver?where=image&sm=tab_jum&query=" + keyword, 
#                   headers={'User-Agent':'Mozilla/5.0'})
#html = bs(raw.text, 'html.parser')


#url = baseUrl + quote_plus(plusUrl) # url로 이동하기위한 쿼리문자열 만들기
html = urlopen(url) # url 열기
soup = bs(html, "html.parser")
img = soup.find_all(class_='_img', limit = 50) #클래스가 _img인 사진 50장으로 제한



# 반복 수집
n = 1
for i in img: # 이미지를 50개 저장하기 위한 반복문
    imgUrl = i['data-source'] 
    with urlopen(imgUrl) as f:
        with open(search_url + str(n) + '.jpg', 'wb') as h: # 이미지 + 사진번호 + 확장자는 jpg
            img = f.read() #이미지 읽기
            h.write(img) # 이미지 저장
    n += 1
print('다운로드 완료')
# Out:
# https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EC%95%84%EC%9D%B4%EC%9C%A0
# 다운로드 완료

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus
from urllib.request import urlretrieve


baseUrl = "https://search.naver.com/search.naver?where=image&sm=tab_jum&query="
plusUrl = input("검색어를 입력하세요 : ")

url = baseUrl + quote_plus(plusUrl)
print(url)
html = urlopen(url)
soup = bs(html, "html.parser")
img = soup.findAll("img")
for i in range(len(img)) :
    a = img[i].attrs[""]
    urlretrieve(a, "./img/"+"{}.jpg".format(i))

print("다운로드 완료")
# Out:
# 검색어를 입력하세요 :  강아지
# https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EA%B0%95%EC%95%84%EC%A7%80
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-4f4f9cee66eb> in <module>
#      14 img = soup.findAll("img")
#      15 for i in range(len(img)) :
# ---> 16     a = img[i].attrs["class"]
#      17     urlretrieve(a, "./img/"+"{}.jpg".format(i))
#      18
#
# KeyError: 'class'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus

baseUrl = "https://search.naver.com/search.naver?where=image&sm=tab_jum&query="
plusUrl = input("검색어를 입력하세요 : ")

url = baseUrl + quote_plus(plusUrl)
print(url)
html = urlopen(url)
soup = bs(html, "html.parser")
img = bs.findAll("_image._listImage", limit = 10)

n = 1
for i in img :
    imgUrl = i["data-source"]
    with urlopen(imgUrl) as f :
        with open(plusUrl + str(n) + ".jpg", "wb") as h :
            img = f.read()
            h.write(img)
    n += 1
print("다운로드 완료")
# Out:
# 검색어를 입력하세요 :  아이유
# https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EC%95%84%EC%9D%B4%EC%9C%A0
# 다운로드 완료

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus

baseUrl = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=' # 네이버 검색url
plusUrl = input('검색어를 입력하세요 : ') # 검색어 질문
url = baseUrl + quote_plus(plusUrl) # url로 이동하기위한 쿼리문자열 만들기
html = urlopen(url) # url 열기
soup = bs(html, "html.parser")
img = soup.findAll("img", limit = 50) #클래스가 _img인 사진 50장으로 제한
#img = soup.find_all("img._image_listImage", limit = 50) #클래스가 _img인 사진 50장으로 제한

n = 1
for i in img: # 이미지를 50개 저장하기 위한 반복문
    imgUrl = i['data-source'] 
    with urlopen(imgUrl) as f:
        with open('./img/' + plusUrl + str(n)+'.jpg','wb') as h: # 이미지 + 사진번호 + 확장자는 jpg
            img = f.read() #이미지 읽기
            h.write(img) # 이미지 저장
    n += 1
print('다운로드 완료')
# Out:
# 검색어를 입력하세요 :  사과
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-1dc71a2b67ac> in <module>
#      13 n = 1
#      14 for i in img: # 이미지를 50개 저장하기 위한 반복문
# ---> 15     imgUrl = i['data-source']
#      16     with urlopen(imgUrl) as f:
#      17         with open('./img/' + plusUrl + str(n)+'.jpg','wb') as h: # 이미지 + 사진번호 + 확장자는 jpg
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1404         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1405         and throws an exception if it's not there."""
# -> 1406         return self.attrs[key]
#    1407
#    1408     def __iter__(self):
#
# KeyError: 'data-source'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus

import ssl
ssl._create_default_https_context = ssl._create_unverified_context # 보안을 회피하여 다운로드

baseUrl = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=' # 네이버 검색url
plusUrl = input('검색어를 입력하세요 : ') # 검색어 질문
url = baseUrl + quote_plus(plusUrl) # url로 이동하기위한 쿼리문자열 만들기
html = urlopen(url) # url 열기
soup = bs(html, "html.parser")

img = soup.find_all("_image._listImage", limit = 10)
print(img)
# Out:
# 검색어를 입력하세요 :  아이유
# []

# %%
import requests
import re
import time
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus

t1 = time.time()
# 정규식 선언
reg = re.compile('oimgurl: ".{0,300}", cpid')

baseUrl = 'https://search.daum.net/search?w=img&nil_search=btn&DA=NTB&enc=utf8&q='
plusUrl = input('검색어를 입력하세요 : ') # 검색어 질문
url = baseUrl + quote_plus(plusUrl)
html = requests.get(url=url)
html_raw_data = str(html.content)

reg_iter = reg.finditer(html_raw_data)

#url 이미지를 저장하는 함수
def save_img(idx, img_url):
    res = requests.get(img_url).content
    with open("./img/" + f'{idx}.jpg', 'wb') as f:
        # 이미지 관련 작업은 pillow 모듈을 사용하는게 좋다
        # 예제에서는 사용 안함 (따로 설치가 필요)  
        f.write(res)
        print(f'save {idx}')

for idx, res_data in enumerate(reg_iter):
    # url 을 뽑아내는 전처리 작업
    img_url = res_data.group().split('oimgurl:')[1].split(', cpid')[0].replace('"', '')
    save_img(idx, img_url)

t2 = time.time()

print(t2-t1)
# Out:
# 검색어를 입력하세요 :  아이유
# save 0
# save 1
# save 2
# save 3
# save 4
# save 5
# save 6
# save 7
# save 8
# save 9
# save 10
# save 11
# save 12
# save 13
# save 14
# save 15
# save 16
# save 17
# save 18
# save 19
# save 20
# save 21
# save 22
# save 23
# save 24
# save 25
# save 26
# save 27
# save 28
# save 29
# save 30
# save 31
# save 32
# save 33
# save 34
# save 35
# save 36
# save 37
# save 38
# save 39
# save 40
# save 41
# save 42
# save 43
# save 44
# save 45
# save 46
# save 47
# save 48
# save 49
# save 50
# save 51
# save 52
# save 53
# save 54
# save 55
# save 56
# save 57
# save 58
# save 59
# save 60
# save 61
# save 62
# save 63
# save 64
# save 65
# save 66
# save 67
# save 68
# save 69
# save 70
# save 71
# save 72
# save 73
# save 74
# save 75
# save 76
# save 77
# save 78
# save 79
# 10.153100967407227

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\CPB06GameN\\Python'

# %%
os.chdir("data_crawling")

# %%
import os
import sys
import urllib.request
from selenium import webdriver
from time import sleep
from bs4 import BeautifulSoup

keyword = input('검색어 : ')
maxImages = int(input('다운로드 시도할 최대 이미지 수 : '))

# 프로젝트에 미리 생성해놓은 crawled_img폴더 안에 하위 폴더 생성
# 폴더명에는 입력한 키워드, 이미지 수 정보를 표시함
path = 'crawled_img/'+keyword+'_'+str(maxImages)

try:
    # 중복되는 폴더 명이 없다면 생성
    if not os.path.exists(path):
        os.makedirs(path)
    # 중복된다면 문구 출력 후 프로그램 종료
    else:
        print('이전에 같은 [검색어, 이미지 수]로 다운로드한 폴더가 존재합니다.')
        sys.exit(0)
except OSError:
    print ('os error')
    sys.exit(0)

pages = int((maxImages-1)/100)+1 #한 페이지당 표시되는 이미지 수(100)을 참고하여 확인할 페이지 수 계산
imgCount = 0 # 추출 시도 이미지 수
success = 0 # 추출 성공 이미지 수
finish = False # 이미지에 모두 접근했는지 여부

# 크롬 드라이버 설정
# (크롤링할 때 웹 페이지 띄우지 않음, gpu 사용 안함, 한글 지원, user-agent 헤더 추가)
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('headless')
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('lang=ko_KR')
chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36")
driver = webdriver.Chrome('C:\chromedriver\chromedriver.exe',chrome_options=chrome_options)

for i in range(1,int(pages)+1):
    #웹 페이지 접근 후 1초동안 로드를 기다림
    driver.get('https://pixabay.com/images/search/'+keyword+'/?pagi='+str(i))
    sleep(1)

    #크롤링이 가능하도록 html코드 가공
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')

    imgs = soup.select('div.flex_grid.credits.search_results img') #요소 선택

    #마지막 페이지 여부 결정
    lastPage=False
    if len(imgs)!=100:
        lastPage=True

    #5번 제목에서 설명함
    for img in imgs:
        srcset = ""
        if img.get('srcset')==None:
            srcset = img.get('data-lazy-srcset')
        else: 
            srcset = img.get('srcset')


        src = ""
        if len(srcset):
            src = str(srcset).split()[0] #가장 작은 사이즈의 이미지 경로 추출
            print(src)
            filename = src.split('/')[-1] #이미지 경로에서 날짜 부분뒤의 순 파일명만 추출
            print(filename)
            saveUrl = path+'/'+filename #저장 경로 결정
            print(saveUrl)

            #파일 저장
            #user-agent 헤더를 가지고 있어야 접근 허용하는 사이트도 있을 수 있음(pixabay가 이에 해당)
            req = urllib.request.Request(src, headers={'User-Agent': 'Mozilla/5.0'})
            try:
                imgUrl = urllib.request.urlopen(req).read() #웹 페이지 상의 이미지를 불러옴
                with open(saveUrl,"wb") as f: #디렉토리 오픈
                    f.write(imgUrl) #파일 저장
                success+=1
            except urllib.error.HTTPError:
                print('에러')
                sys.exit(0)

        imgCount+=1

        if imgCount==maxImages:
            finish = True #입력한 이미지 수 만큼 모두 접근했음을 알림
            break
    
    #finish가 참이거나 더 이상 접근할 이미지가 없을 경우 크롤링 종료
    if finish or lastPage:
        break

print('성공 : '+str(success)+', 실패 : '+str(maxImages-success))
